# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#                                                  heading  \
# 0                            Before you kill yourself...
# 1                                           the fast way
# 2      hislife.com/sendmessage.php" rel="nofollow" ac...
# 3                                       Suicide Hotlines
# 4      Do NOT agree with someone that everything is h...
# 5      hislife.com/sendmessage.php" rel="nofollow" ac...
# 6      Report members who share personal contact info...
# 7      hislife.com/sendmessage.php" rel="nofollow" ac...
# 8                                  Yeah, what the hay...
# 9      hislife.com/sendmessage.php" rel="nofollow" ac...
# 10     I don't want to die but I don't want to live a...
# 11     Weird suicide feeling? Dissapointed with the w...
# 12     hislife.com/sendmessage.php" rel="nofollow" ac...
# 13     hislife.com/sendmessage.php" rel="nofollow" ac...
# 14                                           Am I crazy?
# ...

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (8252, 2)

# %%
# removing html tags
from bs4 import BeautifulSoup
df['post'] = [BeautifulSoup(post).get_text().encode('utf-8') for post in df['post']]
# Out:
# C:\Users\ARCHIT\Anaconda3\lib\site-packages\bs4\__init__.py:273: UserWarning: "b'.................................................. ............'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\ARCHIT\Anaconda3\lib\site-packages\bs4\__init__.py:273: UserWarning: "b'...'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\ARCHIT\Anaconda3\lib\site-packages\bs4\__init__.py:273: UserWarning: "b'............'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\ARCHIT\Anaconda3\lib\site-packages\bs4\__init__.py:273: UserWarning: "b'..'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
# ...

# %%
df['post'] = [' '.join(post.split()) for post in df['post']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-c05ef221a45a> in <module>()
# ----> 1 df['post'] = [' '.join(post.split()) for post in df['post']]
#
# <ipython-input-21-c05ef221a45a> in <listcomp>(.0)
# ----> 1 df['post'] = [' '.join(post.split()) for post in df['post']]
#
# TypeError: sequence item 0: expected str instance, bytes found

# %%
df.to_csv('D:\suicide_pred\cleaner\datacleaned.csv')
